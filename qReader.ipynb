# %% [markdown]
# # qReader
# - Dump link to article at one place with no extra effort while adding
# - Present list of article based on [current state](#States) of the user instead of state of the user when the article is added to queue
# - Rescue bookmarked article which are never read due to imbalance in inflow and outflow
# - Engine to map article to user state
#
# ## States
# - Commute
#   - Mornming commute
#   - Evenening commute
# - Coffee shop
# - Early morning read (kickstarter)
# - Late night read (sleep inducer)
# - Walk
# - Driving
# - Travelling
# - Standing in line
# - Research
# - Weekend
#   - Morning
#   - Afternoon
#   - Evening
#
# ## Features of each state
# - Commute
#   - Moderate length reads (could be long depending upon commute)
#   - Can be read in noisy environment
#   - Easy subject
#   - Easy flow of language
#   - Morning commute -> sentiment = uplifting
#   - Evening commute -> sentiment = tired
# - Coffee shop
#   - Sentiment = relax
#   - Long read
#   - Can be read in ambient noise
#   - Moderate to complex subject
#   - Complex flow of language
# - Early monring (weekdays)
#   - Sentiment = uplifting/inspiring
#   - Comlpex subject
#   - Short
#   - Recent events
#   - Complex flow of language
# - Late nighter
#   - Sentiment = soothing/sleepy
#   - Long reads
#   - Possibly boring
#   - Easy flow
#   - Auditory = soothing voice
# - Walk/Driving
#   - Sentiment - Receptive/Informative
#   - Very easy to understand
#   - Doesn't need much attention
#   - Long read
#   - Auditory = stern voice
# - Travelling
#   - Sentiment = neutral
#   - Long reads
#   - Can be read in noisy environment
#   - Moderate to complex subject
#   - East flow of language
#   - Visual
# - Standing in line
#   - Sentiment = neutral
#   - Very short attention, can be interrupted
#   - Short reads
#   - Easy flow of language
#   - Easy subject
# - Weekend
#   - Complex subject
#   - Complex flow
#   - Long reads
#   - Auditory = stern voice
#   - Morning = Recent events, uplifting
#   - Evening = Receptive/Informative
#
# ## Article features
# - Subject - (easy, moderate, complex)
# - Length - (short\[<6 min\], medium\[6-30 min\], long\[>30 min\])
# - Sentiment = uplifiting, calming, soothing, neutral, inspiring, controversial
# - Flow of language (global property of the article, how subject is explained) -> easy, difficult
#   - Attention required
# - Structure (local property of the article, length of prose, etc) -> easy, difficult
#   - Attention required
#   - Interruptability
# - Text-to-speech convertability (check whether pre formatted text, codes)
# - Is visual? (Count number of images)

# %% [markdown]
# ## Subject complexity
#
# #### Step 1
# - Convert article to predefined subject
# - Predefined subject to their complexity
# #### Step 2
# - Check if the article is on hacker news/reddit
# - Check how contravertial it on hacker news/reddit
# - Relevant links
#   - [reddit scoring1](https://scienceblogs.com/builtonfacts/2013/01/16/the-mathematics-of-reddit-rankings-or-how-upvotes-are-time-travel)
#   - [reddit scoring2](https://www.evanmiller.org/how-not-to-sort-by-average-rating.html)
#   - [reddit api python](https://praw.readthedocs.io/en/latest/getting_started/quick_start.html)
#   - [reddit api](https://www.reddit.com/dev/api#listings)
#   - [HN scoring](http://www.righto.com/2013/11/how-hacker-news-ranking-really-works.html)
#   - [HN search](https://hn.algolia.com/?query=<QUERY>&sort=byDate&prefix&page=0&dateRange=all&type=story)
#   - [HN](https://github.com/minimaxir/hacker-news-undocumented)

# %% [markdown]
# ## Readability of the text
#
# - [Readability Index in Python](https://www.geeksforgeeks.org/readability-index-pythonnlp/)
# - [TextStat](https://pypi.org/project/textstat/)
# - [Texstacy](https://github.com/chartbeat-labs/textacy)
# - pip install readability-lxml
# - pip install texacy
# python -m spacy download en
# - PyTeaser

# %% [markdown]
# ## HTML to text
#
# https://newspaper.readthedocs.io/en/latest/
#
# https://pypi.org/project/PyOpenGraph/
#
# https://pypi.org/project/pypandoc/
#
# https://w3lib.readthedocs.io/en/latest/index.html
#
# Build pipeline
# - Extract article html with -> https://github.com/codelucas/newspaper
# - Use pandoct to convert from html to markdown
# - Use markdown widget to display
# - Use text to decide
#   - Length
#   - Sentiment
#
# Issues
# - JS rendered webpage
#   - Sol: https://github.com/jeanphix/Ghost.py
# - Crayon syntax highlighter
# - Headless browser
#   - https://github.com/machinepublishers/jbrowserdriver

# %% [markdown]
# ## Sentiment analysis
#
# - [Text classification](https://medium.com/@ageitgey/text-classification-is-your-new-secret-weapon-7ca4fad15788)

# %% [markdown]
# # Implementation

# %% [markdown]
# ## Server-side
# - Link canonization
# - Link to id
# - Parsing failure detector
# - title, author, summary extraction
# - content extraction in markdown
# - topic complexity determination
# - article readability determination
# - article length calculation based on article size, complexity and readability
# - sentiment analysis
# - text-to-speeach score (?)
# - visual score (??)

# %% [markdown]
# #### Installing dependencies
# ```
# pip3 install newspaper3k
# pip3 install pypandoc
# pip3  install w3lib
# ```

# %% [markdown]
# Difference between 1. Subject complexity, 2. Attention, 3. Readiblity
# =================================================
#
#
# --- Article ---
#
# When teenagers get bored, they struggle to stay motivated and often lose sight of their goals. Boredom often results in apathy, so many teens neglect their school work, extracurricular activities and household chores when they feel lethargic and unmotivated. For some teens, boredom leads to trouble because they engage in unhealthy activities to boost their excitement level. Most teens feel frustrated when they experience long periods of boredom.
#
# Bored teens often experience low energy levels that affect their school work, attitudes, goals and attention spans. Persistent boredom often leads to low energy levels, loss of concentration, lack of motivation and slow thinking skills, according to PsychCentral.com. A bored teenager might skip school or neglect family chores because he doesn't have the energy or motivation to accomplish tasks. Parents can help by ensuring that their teen makes it to school, completes his homework and fulfills his home responsibilities. Parents might need to use an alarm clock, activity chart or other time-management strategies to make sure their teen doesn't sleep all day.
#
# --- Article End ---
#
# 1. Subject complexity - based on the subject matter.
#     a. Find the keyboards -> Teenagers, bordom, struggle, school, psychology
#     b. See how contraversial is this article on HN, reddit
#     c. Popularity on HN, reddit
#
# 2. Attention -> Local property : Convert the article to its basic units -> nouns, verbs, adjectives. And see whether some pattern of the sententence arrangement needs more attention than other patterns. Possible use of ML with LSTM networks?
# 3. Readibilty score ->  Global property : Arrangement of the article subject matter e.g. paragraphs, examples, references to other parts of the article etc. LSTM at paragraph level, with instead of sentence references, we need a way to find references to paragraphs.Standard way to measure readibility score using Readability Index. Various available Readabilty Score Determination Methods/Formaulae:-
#         1) The Dale–Chall formula
#         2) The Gunning fog formula
#         3) Fry readability graph
#         4) McLaughlin’s SMOG formula
#         5) The FORCAST formula
#         6) Readability and newspaper readership
#         7) Flesch Score

# %% [markdown]
# Readibility score:
#     1. Content quality - Specificity
#     2. Verbosity
#     3. Reader interest
#     4. Oragnization quality
#
# Attention
#     1. Structure of the article
#     2. Reader interest
#
#
# Subject complexity
#     1. Article -> Text -> Category (Google ML) -> Complexity
#     2. HN/reddit -> Upvote/Comment ratio
#     3. Keywords(article) -> Keyword complexity?

# %%
How well-written is this article? -> Flow/Readiblity
How well does the text fit together? -> Flow/Readiblity
How easy was it to understand? -> Attention
How interesting is this article? -> Complexity
